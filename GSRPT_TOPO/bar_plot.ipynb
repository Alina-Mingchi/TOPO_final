# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
labels = ['Urban_nadir', 'Urban_oblique', 'Rural_nadir', 'Rural_oblique']
less_1 = [25,17,5,6]
less_2 = [0,8,11,10]
less_3 = [0,0,7,7]

less_1 = np.array(less_1)/25*100
less_2 = np.array(less_2)/25*100
less_3 = np.array(less_3)/25*100

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots(figsize=(4,6))

ax1 = ax.bar(labels, less_1, width, label='< 1m',color='#3ba1c5')
ax2 = ax.bar(labels, less_2, width, bottom=less_1,
       label='< 2m',color='#7cc0d8')
ax3 = ax.bar(labels, less_3, width, bottom=less_1+less_2,
       label='< 3m',color='#bee0ec')

for r1, r2, r3 in zip(ax1, ax2, ax3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    if h1>0:
        plt.text(r1.get_x() + r1.get_width() / 2., h1 , "%d" % h1+ "%", ha="center", va="top", color="black", fontsize=11)
    if h2>0:
        plt.text(r2.get_x() + r2.get_width() / 2., h1 + h2 , "%d" % h2+ "%", ha="center", va="top", color="black", fontsize=11)
    if h3>0:
        plt.text(r3.get_x() + r3.get_width() / 2., h1+h2+h3, "%d" % h3+ "%", ha="center", va="top", color="black", fontsize=11)
    

ax.set_ylabel('Percentage of prediction that falls under thresholded error [%]')
ax.set_title('Upsamling by a factor 8')
ax.legend(bbox_to_anchor=(1.01, 1), loc='upper left', borderaxespad=0.)    
plt.xticks(rotation=45, ha='right')
plt.savefig('GSRPT_x8_bar.png',bbox_inches='tight')
plt.show()

# %%
labels = ['Urban_nadir', 'Urban_oblique', 'Rural_nadir', 'Rural_oblique']
lesss_1 = [16,0,0,0]
lesss_3 = [8,20,16,12]
lesss_5 = [1,5,8,11]

lesss_1 = np.array(lesss_1)/25*100
lesss_3 = np.array(lesss_3)/25*100
lesss_5 = np.array(lesss_5)/25*100

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots(figsize=(4,6))

ax1 = ax.bar(labels, lesss_1, width, label='< 1m',color='#f9901b')
ax2 = ax.bar(labels, lesss_3, width, bottom=lesss_1,
       label='< 3m',color='#fbb15f')
ax3 = ax.bar(labels, lesss_5, width, bottom=lesss_3+lesss_1,
       label='< 5m',color='#fddebb')


for r1, r2, r3 in zip(ax1, ax2, ax3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    if h1>0:
        plt.text(r1.get_x() + r1.get_width() / 2., h1 , "%d" % h1 + "%", ha="center", va="top", color="black", fontsize=11)
    if h2>0:
        plt.text(r2.get_x() + r2.get_width() / 2., h1 + h2 , "%d" % h2+ "%", ha="center", va="top", color="black", fontsize=11)
    if h3>0:
        plt.text(r3.get_x() + r3.get_width() / 2., h1+h2+h3, "%d" % h3+ "%", ha="center", va="top", color="black", fontsize=11)
    

ax.set_ylabel('Percentage of prediction that falls under thresholded error [%]')
ax.set_title('Upsamling by a factor 40')
ax.legend(bbox_to_anchor=(1.01, 1), loc='upper left', borderaxespad=0.)    
plt.xticks(rotation=45, ha='right')
plt.savefig('GSRPT_x40_bar.png',bbox_inches='tight')

plt.show()

# %%
labels = ['Urban_nadir', 'Urban_oblique', 'Rural_nadir', 'Rural_oblique']
les_2 = [0,1,0,7]
les_4 = [19,14,9,13]
les_6 = [6,5,9,4]

les_2 = np.array(les_2)/25*100
les_4 = np.array(les_4)/25*100
les_6 = np.array(les_6)/25*100

width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots(figsize=(4,6))

ax1 = ax.bar(labels, les_2, width, label='< 2m',color='#249a29')
ax2 = ax.bar(labels, les_4, width, bottom=les_2,
       label='< 4m',color='#66b869')
ax3 = ax.bar(labels, les_6, width, bottom=les_4+les_2,
       label='< 6m',color='#bde1bf')


for r1, r2, r3 in zip(ax1, ax2, ax3):
    h1 = r1.get_height()
    h2 = r2.get_height()
    h3 = r3.get_height()
    if h1>0:
        plt.text(r1.get_x() + r1.get_width() / 2., h1 , "%d" % h1 + "%", ha="center", va="top", color="black", fontsize=11)
    if h2>0:
        plt.text(r2.get_x() + r2.get_width() / 2., h1 + h2 , "%d" % h2+ "%", ha="center", va="top", color="black", fontsize=11)
    if h3>0:
        plt.text(r3.get_x() + r3.get_width() / 2., h1+h2+h3, "%d" % h3+ "%", ha="center", va="top", color="black", fontsize=11)
    

ax.set_ylabel('Percentage of prediction that falls under thresholded error [%]')
ax.set_title('Upsamling by a factor 90')
ax.legend(bbox_to_anchor=(1.01, 1), loc='upper left', borderaxespad=0.)    
plt.xticks(rotation=45, ha='right')
plt.savefig('GSRPT_x90_bar.png',bbox_inches='tight')

plt.show()

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.5       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots(figsize=(4,10))

ax.bar(labels, men_means, width, yerr=men_std, label='Men',color='b')
ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='Women',color='r')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend(bbox_to_anchor=(1.01, 1), loc='upper left', borderaxespad=0.)    

plt.savefig('temp_bar.png',bbox_inches='tight')
plt.show()

# %%
A = [45, 17, 47]
B = [91, 70, 72]

fig = plt.figure(facecolor="white")

ax = fig.add_subplot(1, 1, 1)
bar_width = 0.5
bar_l = np.arange(1, 4)
tick_pos = [i + (bar_width / 2) for i in bar_l]

ax1 = ax.bar(bar_l, A, width=bar_width, label="A", color="green")
ax2 = ax.bar(bar_l, B, bottom=A, width=bar_width, label="B", color="blue")
ax.set_ylabel("Count", fontsize=18)
ax.set_xlabel("Class", fontsize=18)
ax.legend(loc="best")
plt.xticks(tick_pos, ["C1", "C2", "C3"], fontsize=16)
plt.yticks(fontsize=16)

for r1, r2 in zip(ax1, ax2):
    h1 = r1.get_height()
    h2 = r2.get_height()
    plt.text(r1.get_x() + r1.get_width() / 2., h1 , "%d" % h1, ha="center", va="top", color="white", fontsize=16, fontweight="bold")
    plt.text(r2.get_x() + r2.get_width() / 2., h1 + h2 , "%d" % h2, ha="center", va="top", color="white", fontsize=16, fontweight="bold")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


data = [[ 66386, 174296,  75131, 577908,  32015],
        [ 58230, 381139,  78045,  99308, 160454],
        [ 89135,  80552, 152558, 497981, 603535],
        [ 78415,  81858, 150656, 193263,  69638],
        [139361, 331509, 343164, 781380,  52269]]

columns = ('Freeze', 'Wind', 'Flood', 'Quake', 'Hail')
rows = ['%d year' % x for x in (100, 50, 20, 10, 5)]

values = np.arange(0, 2500, 500)
value_increment = 1000

# Get some pastel shades for the colors
colors = plt.cm.BuPu(np.linspace(0, 0.5, len(rows)))
n_rows = len(data)

index = np.arange(len(columns)) + 0.3
bar_width = 0.4

# Initialize the vertical-offset for the stacked bar chart.
y_offset = np.zeros(len(columns))

# Plot bars and create text labels for the table
cell_text = []
for row in range(n_rows):
    plt.bar(index, data[row], bar_width, bottom=y_offset, color=colors[row])
    y_offset = y_offset + data[row]
    cell_text.append(['%1.1f' % (x / 1000.0) for x in y_offset])
# Reverse colors and text labels to display the last value at the top.
colors = colors[::-1]
cell_text.reverse()

# Add a table at the bottom of the axes
the_table = plt.table(cellText=cell_text,
                      rowLabels=rows,
                      rowColours=colors,
                      colLabels=columns,
                      loc='bottom')

# Adjust layout to make room for the table:
plt.subplots_adjust(left=0.2, bottom=0.2)

plt.ylabel("Loss in ${0}'s".format(value_increment))
plt.yticks(values * value_increment, ['%d' % val for val in values])
plt.xticks([])
plt.title('Loss by Disaster')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


data = [[ 66386, 174296,  75131, 577908,  32015],
        [ 58230, 381139,  78045,  99308, 160454],
        [ 89135,  80552, 152558, 497981, 603535],
        [ 78415,  81858, 150656, 193263,  69638],
        [139361, 331509, 343164, 781380,  52269]]

columns = ('Freeze', 'Wind', 'Flood', 'Quake', 'Hail')
rows = ['%d year' % x for x in (100, 50, 20, 10, 5)]

values = np.arange(0, 2500, 500)
value_increment = 1000

# Get some pastel shades for the colors
colors = plt.cm.BuPu(np.linspace(0, 0.5, len(rows)))
n_rows = len(data)

index = np.arange(len(columns)) + 0.3
bar_width = 0.4

# Initialize the vertical-offset for the stacked bar chart.
y_offset = np.zeros(len(columns))

# Plot bars and create text labels for the table
cell_text = []
for row in range(n_rows):
    plt.bar(index, data[row], bar_width, bottom=y_offset, color=colors[row])
    y_offset = y_offset + data[row]
    cell_text.append(['%1.1f' % (x / 1000.0) for x in y_offset])
# Reverse colors and text labels to display the last value at the top.
colors = colors[::-1]
cell_text.reverse()

# Add a table at the bottom of the axes
the_table = plt.table(cellText=cell_text,
                      rowLabels=rows,
                      rowColours=colors,
                      colLabels=columns,
                      loc='bottom')

# Adjust layout to make room for the table:
plt.subplots_adjust(left=0.2, bottom=0.2)

plt.ylabel("Loss in ${0}'s".format(value_increment))
plt.yticks(values * value_increment, ['%d' % val for val in values])
plt.xticks([])
plt.title('Loss by Disaster')

plt.show()
