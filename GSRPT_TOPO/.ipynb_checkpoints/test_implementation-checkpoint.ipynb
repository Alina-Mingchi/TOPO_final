# %%
import os
os.environ["CC"] = "gcc"
os.environ["CXX"] = "gcc"

# %%
import sys
sys.path.append('/usr/lib/python3/dist-packages')
print(sys.path)
# Out:
# ['/home/beast2020/Desktop/mingchi/PixTransform-save_params', '/home/beast2020/anaconda3/lib/python38.zip', '/home/beast2020/anaconda3/lib/python3.8', '/home/beast2020/anaconda3/lib/python3.8/lib-dynload', '', '/home/beast2020/.local/lib/python3.8/site-packages', '/home/beast2020/anaconda3/lib/python3.8/site-packages', '/home/beast2020/.local/lib/python3.8/site-packages/IPython/extensions', '/home/beast2020/.ipython', '/usr/lib/python3/dist-packages']

# %%
import os
os.environ["OMP_PROC_BIND"] = os.environ.get("OMP_PROC_BIND", "true")

import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate
# %matplotlib inline

from pix_transform.pix_transform import PixTransform
from baselines.baselines import bicubic
from utils.utils import downsample,align_images
from prox_tv import tvgen
from utils.plots import plot_result

# %% [markdown]
# ## EPFL nadir

# %%
# %env CUDA_VISIBLE_DEVICES=1

# %%
import imageio
import torch

# %%
directory = os.path.dirname(os.getcwd())
directory
# Out:
# '/home/beast2020/Desktop/mingchi'

# %%
rgb_dir = directory+'/EPFL_10_newsample_nadir/rgb/'
_files = os.listdir(rgb_dir)
_files.sort()
_rgb_files = [rgb_dir + f for f in _files]
_rgb_files.sort()
print(_rgb_files)

dist_dir = directory+'/EPFL_10_newsample_nadir/dist/'
_files = os.listdir(dist_dir)
_files.sort()
_dist_files = [dist_dir + f for f in _files]
_dist_files.sort()
print(_dist_files)
# Out:
# ['/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/rgb/EPFL_2020-09-17_00257_100_0039_0025.png', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/rgb/EPFL_2020-09-17_00259_100_0039_0027.png', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/rgb/EPFL_2020-09-17_00267_100_0039_0035.png', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/rgb/EPFL_2020-09-17_00276_100_0039_0044.png', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/rgb/EPFL_2020-09-17_00277_100_0039_0045.png', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/rgb/EPFL_2020-09-17_00279_100_0039_0047.png', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/rgb/EPFL_2020-09-17_00294_100_0039_0062.png', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/rgb/EPFL_2020-09-17_00302_100_0039_0070.png', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/rgb/EPFL_2020-09-17_00304_100_0039_0072.png', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/rgb/EPFL_2020-09-17_00305_100_0039_0073.png']
# ['/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/dist/EPFL-2020-09-17-planned_00257_100_0039_0025.dat', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/dist/EPFL-2020-09-17-planned_00259_100_0039_0027.dat', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/dist/EPFL-2020-09-17-planned_00267_100_0039_0035.dat', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/dist/EPFL-2020-09-17-planned_00276_100_0039_0044.dat', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/dist/EPFL-2020-09-17-planned_00277_100_0039_0045.dat', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/dist/EPFL-2020-09-17-planned_00279_100_0039_0047.dat', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/dist/EPFL-2020-09-17-planned_00294_100_0039_0062.dat', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/dist/EPFL-2020-09-17-planned_00302_100_0039_0070.dat', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/dist/EPFL-2020-09-17-planned_00304_100_0039_0072.dat', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/dist/EPFL-2020-09-17-planned_00305_100_0039_0073.dat']

# %%
guide_imgs = []
target_imgs= []

for num in range(len(_rgb_files)):
    rgb_img = imageio.imread(_rgb_files[num])
    guide_imgs.append(rgb_img)
    dist_img = torch.load(_dist_files[num-1])
    dist_img = dist_img.detach().cpu().numpy()
    target_imgs.append(dist_img)
        
guide_imgs = np.asarray(guide_imgs)
guide_imgs = np.einsum('ijkl->iljk', guide_imgs)        
target_imgs = np.asarray(target_imgs)

# %%
print(guide_imgs.shape)
print('max value in the image is: ' + str(guide_imgs.max()))
print('min value in the image is: ' + str(guide_imgs.min()))
# Out:
# (10, 3, 480, 720)
# max value in the image is: 255
# min value in the image is: 0

# %%
print(target_imgs.shape)
print('max value in the image is: ' + str(target_imgs.max()))
print('min value in the image is: ' + str(target_imgs.min()))
# Out:
# (10, 480, 720)
# max value in the image is: 97.91275
# min value in the image is: 49.04693

# %%
####  define parameters  ########################################################
params = {'img_idxs' : [], # idx images to process, if empty then all of them
            
          'scaling': 8,
          'greyscale': False, # Turn image into grey-scale
          'channels': -1,
          
          'spatial_features_input': True,
          'weights_regularizer': [0.0001, 0.001, 0.0001], # spatial color head
          'loss': 'l1',
 
          'optim': 'adam',
          'lr': 0.001,
                  
          'batch_size': 32,
          'iteration': 1024*60*90//32, # could //4 or //16 for debugging, so to save time
                  
          'logstep': 16,
          
          'final_TGV' : False, # Total Generalized Variation in post-processing
          'align': False, # Move image around for evaluation in case guide image and target image are not perfectly aligned
          'delta_PBP': 1, # Delta for percentage of bad pixels 
         }

# %%
directory
# Out:
# '/home/beast2020/Desktop/mingchi'

# %%
if len(params['img_idxs'])==0:
    idxs = np.array(range(0,target_imgs.shape[0]))
else:
    idxs = params['img_idxs']

for n_image,idx in enumerate(idxs):
    
    print("####### image {}/{} - image idx {} ########".format(n_image+1,len(idxs),idx))
    
    guide_img = guide_imgs[idx]
    target_img = target_imgs[idx]
    source_img = downsample(target_img,params['scaling'])
    save_path = directory+'/saved_model_EPFL_nadir/model'+str(idx)+'.pt'
    # check if the directory exist
    os.makedirs(os.path.dirname(save_path),exist_ok=True)
    
    bicubic_target_img = bicubic(source_img=source_img, scaling_factor=params['scaling'])
    
    predicted_target_img = PixTransform(guide_img=guide_img,source_img=source_img,params=params,target_img=target_img, path = save_path)
    


    if params['final_TGV'] :
        print("applying TGV...")
        predicted_target_img = tvgen(predicted_target_img,[0.1, 0.1],[1, 2],[1, 1])
        
    if params['align'] :
        print("aligning...")
        target_img,predicted_target_img = align_images(target_img,predicted_target_img)

    f, ax = plot_result(guide_img,source_img,predicted_target_img,bicubic_target_img,target_img)
    plt.show()
    
    if target_img is not None:
        # compute metrics and plot results
        MSE = np.mean((predicted_target_img - target_img) ** 2)
        MAE = np.mean(np.abs(predicted_target_img - target_img))
        PBP = np.mean(np.abs(predicted_target_img - target_img) > params["delta_PBP"])

        print("MSE: {:.3f}  ---  MAE: {:.3f}  ---  PBP: {:.3f}".format(MSE,MAE,PBP))
        print("\n\n")
# Out:
# ####### image 1/10 - image idx 0 ########
#   0%|          | 0/1024 [00:00<?, ?it/s]
# ----------MSE----------
# (64,)
# [33.438442   6.992129   6.293433   6.724288   5.510071   4.7193956
#   4.8272867  5.107815   4.4781194  4.317777   4.5578117  4.232845
#   4.5470514  4.3427596  3.957603   3.8579152  4.1494126  3.6972244
#   3.6576204  3.684652   3.7484794  3.4314644  3.5368996  3.6780827
#   3.4312356  3.3459852  3.6859434  3.5401475  3.1935594  3.4025927
#   3.5493093  3.0990264  4.0939875  3.2743716  2.9858334  3.085064
#   3.2754521  3.1155758  2.9797504  2.915247   3.22377    3.4733677
#   2.8373435  3.0031948  2.8880124  3.1441956  2.79478    3.3053725
########
#   0%|          | 0/1024 [00:00<?, ?it/s]
# ----------MSE----------
# (64,)
# [26.30003    7.9880843  5.780099   4.6199126  4.5672574  4.267406
#   4.258852   3.8722405  4.481573   3.6566818  3.8451917  4.8699427
#   3.7570717  3.5048065  3.4733374  3.431596   3.434035   3.3579578
#   3.597207   3.327318   3.2910938  3.054341   3.5019453  3.0115185
#   3.202513   3.3418367  3.4143403  3.2897801  3.0490682  2.8540747
#   2.8394523  3.0737977  2.8833401  3.0184045  3.329681   2.9044275
#   2.9145432  2.7383363  2.6883807  2.9403548  2.7570348  2.7934446
#   3.2685232  2.7902505  3.0539894  2.6643813  2.7711635  2.7702422
#   2.6425133  2.6732583  2.6599174  2.7728827  2.5846548  2.5576832
#   2.5454988  2.722235   2.823403   2.792563   2.5135102  2.9301043
#   2.6000652  2.5847094  2.6515355  2.5275943]
# ----------MAE----------
# (64,)
# [3.684432   1.9505374  1.5722324  1.3024237  1.2659451  1.1922799
#  1.2603211  1.198697   1.3375092  1.1330731  1.1841975  1.3632925
#  1.1322042  1.1296608  1.1415107  1.1320099  1.0957525  1.0621629
#  1.1186471  1.0563803  1.0913335  1.0061256  1.0978091  0.9672227
#  1.0610467  1.0732646  1.0468737  1.0614336  0.9916219  0.9365011
#  0.99654114 1.0017209  0.93837893 0.97841436 1.0538408  0.9766909
#  0.9597811  0.92293006 0.9175481  0.9534601  0.9174895  0.9386809
#  0.97215044 0.9408055  1.0156181  0.91157144 0.92186123 0.9274752
#  0.90575457 0.8980671  0.87442154 0.9102881  0.9027215  0.88631654
#  0.8964648  0.92012453 0.97709924 0.9589719  0.8724806  0.9304124
#  0.8908997  0.8972345  0.88626844 0.8813527 ]
# MSE: 2.496  ---  MAE: 0.864  ---  PBP: 0.248

# %% [markdown]
# ### Change upsampling to 16

# %%
####  define parameters  ########################################################
params = {'img_idxs' : [], # idx images to process, if empty then all of them
            
          'scaling': 16,
          'greyscale': False, # Turn image into grey-scale
          'channels': -1,
          
          'spatial_features_input': True,
          'weights_regularizer': [0.0001, 0.001, 0.0001], # spatial color head
          'loss': 'l1',
 
          'optim': 'adam',
          'lr': 0.001,
                  
          'batch_size': 32,
          'iteration': 1024*30*45//32,
                  
          'logstep': 64,
          
          'final_TGV' : False, # Total Generalized Variation in post-processing
          'align': False, # Move image around for evaluation in case guide image and target image are not perfectly aligned
          'delta_PBP': 1, # Delta for percentage of bad pixels 
         }

# %%
# Out:
# ####### image 1/9 - image idx 0 ########
#   0%|          | 0/1024 [00:00<?, ?it/s]

# %%
import torch
torch.cuda.empty_cache()
