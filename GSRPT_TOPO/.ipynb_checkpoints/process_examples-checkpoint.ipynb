# %%
import os

# %%
os.environ["CC"] = "gcc"
os.environ["CXX"] = "gcc"

# %%
import sys
sys.path.append('/usr/lib/python3/dist-packages')
print(sys.path)
# Out:
# ['/Users/felicity/Desktop/Super-resolution-drones-depth-images/ICCV2019/PixTransform-master', '/Library/Frameworks/Python.framework/Versions/3.7/lib/python37.zip', '/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7', '/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/lib-dynload', '', '/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages', '/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/extensions', '/Users/felicity/.ipython', '/usr/lib/python3/dist-packages']

# %%
import os
os.environ["OMP_PROC_BIND"] = os.environ.get("OMP_PROC_BIND", "true")

import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate
# %matplotlib inline

from pix_transform.pix_transform import PixTransform
from baselines.baselines import bicubic
from utils.utils import downsample,align_images
from prox_tv import tvgen
from utils.plots import plot_result

# %%
####  load dataset  #############################################################

data_path = "./data/depth_sample_images.npz"

dataset = np.load(data_path)
target_imgs = dataset["target_imgs"].squeeze()
guide_imgs =  dataset["guide_imgs"].squeeze()
dataset.close()

####  define parameters  ########################################################
params = {'img_idxs' : [], # idx images to process, if empty then all of them
            
          'scaling': 8,
          'greyscale': False, # Turn image into grey-scale
          'channels': -1,
          
          'spatial_features_input': True,
          'weights_regularizer': [0.0001, 0.001, 0.0001], # spatial color head
          'loss': 'l1',
 
          'optim': 'adam',
          'lr': 0.001,
                  
          'batch_size': 32,
          'iteration': 1024*32*32//32,
                  
          'logstep': 64,
          
          'final_TGV' : False, # Total Generalized Variation in post-processing
          'align': False, # Move image around for evaluation in case guide image and target image are not perfectly aligned
          'delta_PBP': 1, # Delta for percentage of bad pixels 
         }

# %%
if len(params['img_idxs'])==0:
    idxs = np.array(range(0,target_imgs.shape[0]))
else:
    idxs = params['img_idxs']

for n_image,idx in enumerate(idxs):
    
    print("####### image {}/{} - image idx {} ########".format(n_image+1,len(idxs),idx))
    
    guide_img = guide_imgs[idx]
    target_img = target_imgs[idx]
    source_img = downsample(target_img,params['scaling'])

    bicubic_target_img = bicubic(source_img=source_img, scaling_factor=params['scaling'])
    
    predicted_target_img = PixTransform(guide_img=guide_img,source_img=source_img,params=params,target_img=target_img)
    


    if params['final_TGV'] :
        print("applying TGV...")
        predicted_target_img = tvgen(predicted_target_img,[0.1, 0.1],[1, 2],[1, 1])
        
    if params['align'] :
        print("aligning...")
        target_img,predicted_target_img = align_images(target_img,predicted_target_img)

    
    f, ax = plot_result(guide_img,source_img,predicted_target_img,bicubic_target_img,target_img)
    plt.show()
    
    if target_img is not None:
        # compute metrics and plot results
        MSE = np.mean((predicted_target_img - target_img) ** 2)
        MAE = np.mean(np.abs(predicted_target_img - target_img))
        PBP = np.mean(np.abs(predicted_target_img - target_img) > params["delta_PBP"])

        print("MSE: {:.3f}  ---  MAE: {:.3f}  ---  PBP: {:.3f}".format(MSE,MAE,PBP))
        print("\n\n")
# Out:
# ####### image 1/3 - image idx 0 ########
#   0%|          | 0/1024 [00:00<?, ?it/s]
# MSE: 65.031  ---  MAE: 2.008  ---  PBP: 0.167
#
#
#
# ####### image 2/3 - image idx 1 ########
#   0%|          | 0/1024 [00:00<?, ?it/s]
# MSE: 2.964  ---  MAE: 0.419  ---  PBP: 0.036
#
#
#
# ####### image 3/3 - image idx 2 ########
#   0%|          | 0/1024 [00:00<?, ?it/s]
# MSE: 3.478  ---  MAE: 0.825  ---  PBP: 0.192

# %% [markdown]
# ## Check vhm dataset

# %%
####  load dataset  #############################################################

data_path = "./data/vhm_sample_images.npz"

dataset = np.load(data_path)
target_imgs = dataset["target_imgs"].squeeze()
guide_imgs =  dataset["guide_imgs"].squeeze()
dataset.close()

####  define parameters  ########################################################
params = {'img_idxs' : [], # idx images to process, if empty then all of them
            
          'scaling': 8,
          'greyscale': False, # Turn image into grey-scale
          'channels': -1,
          
          'spatial_features_input': True,
          'weights_regularizer': [0.0001, 0.001, 0.0001], # spatial color head
          'loss': 'l1',
 
          'optim': 'adam',
          'lr': 0.001,
                  
          'batch_size': 32,
          'iteration': 1024*32*32//32,
                  
          'logstep': 64,
          
          'final_TGV' : False, # Total Generalized Variation in post-processing
          'align': False, # Move image around for evaluation in case guide image and target image are not perfectly aligned
          'delta_PBP': 1, # Delta for percentage of bad pixels 
         }

# %%
if len(params['img_idxs'])==0:
    idxs = np.array(range(0,target_imgs.shape[0]))
else:
    idxs = params['img_idxs']

for n_image,idx in enumerate(idxs):
    
    print("####### image {}/{} - image idx {} ########".format(n_image+1,len(idxs),idx))
    
    guide_img = guide_imgs[idx]
    target_img = target_imgs[idx]
    source_img = downsample(target_img,params['scaling'])

    bicubic_target_img = bicubic(source_img=source_img, scaling_factor=params['scaling'])
    
    predicted_target_img = PixTransform(guide_img=guide_img,source_img=source_img,params=params,target_img=target_img)
    


    if params['final_TGV'] :
        print("applying TGV...")
        predicted_target_img = tvgen(predicted_target_img,[0.1, 0.1],[1, 2],[1, 1])
        
    if params['align'] :
        print("aligning...")
        target_img,predicted_target_img = align_images(target_img,predicted_target_img)

    
    f, ax = plot_result(guide_img,source_img,predicted_target_img,bicubic_target_img,target_img)
    plt.show()
    
    if target_img is not None:
        # compute metrics and plot results
        MSE = np.mean((predicted_target_img - target_img) ** 2)
        MAE = np.mean(np.abs(predicted_target_img - target_img))
        PBP = np.mean(np.abs(predicted_target_img - target_img) > params["delta_PBP"])

        print("MSE: {:.3f}  ---  MAE: {:.3f}  ---  PBP: {:.3f}".format(MSE,MAE,PBP))
        print("\n\n")
# Out:
# ####### image 1/3 - image idx 0 ########
#   0%|          | 0/1024 [00:00<?, ?it/s]
# MSE: 27.935  ---  MAE: 3.363  ---  PBP: 0.577
#
#
#
# ####### image 2/3 - image idx 1 ########
#   0%|          | 0/1024 [00:00<?, ?it/s]
# MSE: 40.043  ---  MAE: 3.802  ---  PBP: 0.576
#
#
#
# ####### image 3/3 - image idx 2 ########
#   0%|          | 0/1024 [00:00<?, ?it/s]
# MSE: 7.507  ---  MAE: 0.799  ---  PBP: 0.110

# %% [markdown]
# ## EPFL nadir

# %%
# %env CUDA_VISIBLE_DEVICES=1
# Out:
# env: CUDA_VISIBLE_DEVICES=1

# %%
import imageio
import torch

# %%
pwd()
# Out:
# '/home/beast2020/Desktop/mingchi/PixTransform-master'

# %%
rgb_dir = '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/rgb/'
_files = os.listdir(rgb_dir)
_files.sort()
_rgb_files = [rgb_dir + f for f in _files]
_rgb_files.sort()
print(_rgb_files)

dist_dir = '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/dist/'
_files = os.listdir(dist_dir)
_files.sort()
_dist_files = [dist_dir + f for f in _files]
_dist_files.sort()
print(_dist_files)
# Out:
# ['/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/rgb/EPFL_2020-09-17_00257_100_0039_0025.png', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/rgb/EPFL_2020-09-17_00259_100_0039_0027.png', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/rgb/EPFL_2020-09-17_00267_100_0039_0035.png', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/rgb/EPFL_2020-09-17_00276_100_0039_0044.png', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/rgb/EPFL_2020-09-17_00277_100_0039_0045.png', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/rgb/EPFL_2020-09-17_00279_100_0039_0047.png', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/rgb/EPFL_2020-09-17_00294_100_0039_0062.png', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/rgb/EPFL_2020-09-17_00302_100_0039_0070.png', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/rgb/EPFL_2020-09-17_00304_100_0039_0072.png', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/rgb/EPFL_2020-09-17_00305_100_0039_0073.png']
# ['/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/dist/EPFL-2020-09-17-planned_00259_100_0039_0027.dat', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/dist/EPFL-2020-09-17-planned_00267_100_0039_0035.dat', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/dist/EPFL-2020-09-17-planned_00276_100_0039_0044.dat', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/dist/EPFL-2020-09-17-planned_00277_100_0039_0045.dat', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/dist/EPFL-2020-09-17-planned_00279_100_0039_0047.dat', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/dist/EPFL-2020-09-17-planned_00294_100_0039_0062.dat', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/dist/EPFL-2020-09-17-planned_00302_100_0039_0070.dat', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/dist/EPFL-2020-09-17-planned_00304_100_0039_0072.dat', '/home/beast2020/Desktop/mingchi/EPFL_10_newsample_nadir/dist/EPFL-2020-09-17-planned_00305_100_0039_0073.dat']

# %%
guide_imgs = []
target_imgs= []

for num in range(len(_rgb_files)):
    if num != 0:
        rgb_img = imageio.imread(_rgb_files[num])
        guide_imgs.append(rgb_img)
        dist_img = torch.load(_dist_files[num-1])
        dist_img = dist_img.detach().cpu().numpy()
        target_imgs.append(dist_img)
        
guide_imgs = np.asarray(guide_imgs)
guide_imgs = np.einsum('ijkl->iljk', guide_imgs)        
target_imgs = np.asarray(target_imgs)

# %%
guide_imgs.shape
# Out:
# (9, 3, 480, 720)

# %%
guide_imgs[:,:,:60,:90]
# Out:
# array([[[[171, 110, 207, ..., 165, 135, 147],
#          [174, 142, 136, ..., 159, 158, 102],
#          [108, 131, 132, ..., 150, 153, 216],
#          ...,
#          [  0,  21,  47, ...,   9,   9,   8],
#          [ 68,  64,   0, ...,  10,   9,   8],
#          [ 52,   0,   3, ...,  10,   8,   9]],
#
#         [[175, 114, 211, ..., 165, 135, 147],
#          [178, 146, 140, ..., 159, 158, 102],
#          [109, 132, 134, ..., 150, 153, 216],
#          ...,
#          [ 11,  38,  57, ...,  13,  13,  12],
#          [101,  86,   6, ...,  14,  13,  12],
#          [ 95,  10,   7, ...,  14,  12,  13]],
#
#         [[174, 113, 210, ..., 163, 133, 145],
#          [179, 145, 139, ..., 157, 156, 100],
#          [111, 134, 133, ..., 148, 151, 214],
#          ...,
#          [ 38,  54,  66, ...,  12,  12,  11],
#          [134, 109,  17, ...,  13,  12,  11],
#          [127,  31,  19, ...,  13,  11,  12]]],
#
#
#        [[[ 85, 122,  95, ..., 146, 118,  10],
#          [107, 158, 121, ...,  93, 163,  16],
#          [168, 167, 139, ..., 132, 142,  14],
#          ...,
#          [  7,   5,   8, ..., 234, 252, 228],
#          [ 10,   9,  11, ..., 239, 237, 199],
#          [ 10,  10,  12, ..., 255, 231, 215]],
#
#         [[ 85, 122,  97, ..., 138, 116,  20],
#          [107, 158, 123, ...,  85, 158,  24],
#          [170, 169, 141, ..., 122, 133,  20],
#          ...,
#          [ 15,  13,  13, ...,  94, 103, 114],
#          [ 15,  14,  15, ...,  99,  99, 101],
#          [ 14,  14,  13, ..., 101,  82, 107]],
#
#         [[ 83, 120,  96, ..., 135, 119,  32],
#          [105, 156, 122, ...,  82, 162,  37],
#          [167, 166, 138, ..., 120, 138,  34],
#          ...,
#          [ 17,  15,  16, ...,  97, 105, 104],
#          [ 18,  17,  18, ..., 102,  99,  88],
#          [ 17,  17,  17, ..., 112,  88, 104]]],
#
#
#        [[[ 31,  34,  33, ...,   9,   6,  10],
#          [ 26,  29,  28, ...,   9,   9,   7],
#          [ 41,  26,  27, ...,   8,  11,   5],
#          ...,
#          [ 27,  26,  26, ...,   5,   5,   7],
#          [ 60,  68,  51, ...,   5,   6,   5],
#          [104,  90,  87, ...,   8,   6,   4]],
#
#         [[ 47,  50,  49, ...,  11,   8,  11],
#          [ 42,  45,  44, ...,  11,  11,   8],
#          [ 57,  42,  43, ...,  10,  12,   9],
#          ...,
#          [ 41,  40,  39, ...,   9,   9,  11],
#          [ 74,  82,  65, ...,   9,  10,   9],
#          [118, 104, 101, ...,  12,  10,   8]],
#
#         [[ 63,  66,  65, ...,  10,   7,  13],
#          [ 58,  61,  60, ...,  10,  10,  10],
#          [ 73,  58,  59, ...,   9,  14,  10],
#          ...,
#          [ 54,  53,  55, ...,   8,   8,  10],
#          [ 85,  95,  78, ...,   8,   9,   8],
#          [129, 115, 114, ...,  11,   9,   7]]],
#
#
#        ...,
#
#
#        [[[ 67,  83,  85, ...,  89, 131, 134],
#          [ 71,  78, 103, ..., 114, 123, 157],
#          [119, 113,  71, ...,  71,  78,  77],
#          ...,
#          [ 96,  96,  91, ...,  14,  15,  38],
#          [119, 147, 106, ...,  13,  17,  13],
#          [124,  96, 138, ...,  21,  19,  12]],
#
#         [[ 77,  88,  84, ...,  93, 136, 136],
#          [ 75,  83, 108, ..., 118, 125, 159],
#          [118, 117,  81, ...,  73,  80,  77],
#          ...,
#          [ 92,  92,  87, ...,  15,  12,  34],
#          [115, 143, 102, ...,  16,  20,  16],
#          [120,  92, 134, ...,  24,  23,  20]],
#
#         [[ 53,  66,  66, ...,  92, 132, 133],
#          [ 52,  61,  86, ..., 117, 122, 156],
#          [ 97,  94,  56, ...,  72,  79,  75],
#          ...,
#          [ 63,  63,  58, ...,  20,  23,  49],
#          [ 88, 116,  75, ...,  21,  29,  31],
#          [ 95,  67, 109, ...,  29,  32,  31]]],
#
#
#        [[[ 16,  22,  15, ...,   7,  12,  10],
#          [ 26,  30,  27, ...,  14,  14,  14],
#          [ 18,  16,  18, ...,  36,  35,  27],
#          ...,
#          [ 13,  16,  11, ...,   7,   5,   5],
#          [ 16,  16,  14, ...,   6,   5,   4],
#          [ 14,  13,  18, ...,   5,   4,   4]],
#
#         [[ 28,  34,  27, ...,  10,  15,  13],
#          [ 38,  42,  39, ...,  18,  18,  18],
#          [ 28,  26,  28, ...,  46,  45,  37],
#          ...,
#          [ 20,  23,  18, ...,   9,   7,   7],
#          [ 23,  23,  21, ...,   8,   7,   6],
#          [ 21,  20,  25, ...,   7,   6,   6]],
#
#         [[ 40,  46,  39, ...,  15,  20,  18],
#          [ 50,  54,  51, ...,  27,  27,  27],
#          [ 38,  36,  38, ...,  56,  55,  47],
#          ...,
#          [ 30,  33,  28, ...,   8,   6,   6],
#          [ 33,  33,  29, ...,   7,   6,   5],
#          [ 29,  28,  33, ...,   6,   5,   5]]],
#
#
#        [[[  9,  20,  17, ...,   7,   8,   6],
#          [ 13,  16,   8, ...,   4,   7,   5],
#          [  9,   9,  11, ...,   3,   6,   5],
#          ...,
#          [ 15,  15,  10, ...,  61, 135, 106],
#          [ 13,  16,  16, ...,  91,  97, 135],
#          [ 18,  18,  14, ..., 111, 116, 108]],
#
#         [[ 12,  23,  22, ...,   9,  10,   8],
#          [ 16,  21,  13, ...,   6,   9,   7],
#          [ 14,  14,  16, ...,   5,   8,   7],
#          ...,
#          [ 21,  21,  16, ...,  58, 129, 100],
#          [ 19,  22,  22, ...,  85,  91, 129],
#          [ 24,  24,  20, ..., 106, 109, 102]],
#
#         [[ 17,  28,  26, ...,   8,   9,   7],
#          [ 21,  25,  19, ...,   5,   8,   6],
#          [ 20,  20,  22, ...,   4,   7,   6],
#          ...,
#          [ 33,  33,  28, ...,  67, 139, 100],
#          [ 31,  34,  34, ...,  95, 101, 129],
#          [ 36,  36,  32, ..., 113, 117, 104]]]], dtype=uint8)

# %%
target_imgs.shape
# Out:
# (9, 480, 720)

# %%
####  define parameters  ########################################################
params = {'img_idxs' : [], # idx images to process, if empty then all of them
            
          'scaling': 8,
          'greyscale': False, # Turn image into grey-scale
          'channels': -1,
          
          'spatial_features_input': True,
          'weights_regularizer': [0.0001, 0.001, 0.0001], # spatial color head
          'loss': 'l1',
 
          'optim': 'adam',
          'lr': 0.001,
                  
          'batch_size': 32,
          'iteration': 1024*60*90//32,
                  
          'logstep': 64,
          
          'final_TGV' : False, # Total Generalized Variation in post-processing
          'align': False, # Move image around for evaluation in case guide image and target image are not perfectly aligned
          'delta_PBP': 1, # Delta for percentage of bad pixels 
         }

# %%
if len(params['img_idxs'])==0:
    idxs = np.array(range(0,target_imgs.shape[0]))
else:
    idxs = params['img_idxs']

for n_image,idx in enumerate(idxs):
    
    print("####### image {}/{} - image idx {} ########".format(n_image+1,len(idxs),idx))
    
    guide_img = guide_imgs[idx]
    target_img = target_imgs[idx]
    source_img = downsample(target_img,params['scaling'])

    bicubic_target_img = bicubic(source_img=source_img, scaling_factor=params['scaling'])
    
    predicted_target_img = PixTransform(guide_img=guide_img,source_img=source_img,params=params,target_img=target_img)
    


    if params['final_TGV'] :
        print("applying TGV...")
        predicted_target_img = tvgen(predicted_target_img,[0.1, 0.1],[1, 2],[1, 1])
        
    if params['align'] :
        print("aligning...")
        target_img,predicted_target_img = align_images(target_img,predicted_target_img)

    f, ax = plot_result(guide_img,source_img,predicted_target_img,bicubic_target_img,target_img)
    plt.show()
    
    if target_img is not None:
        # compute metrics and plot results
        MSE = np.mean((predicted_target_img - target_img) ** 2)
        MAE = np.mean(np.abs(predicted_target_img - target_img))
        PBP = np.mean(np.abs(predicted_target_img - target_img) > params["delta_PBP"])

        print("MSE: {:.3f}  ---  MAE: {:.3f}  ---  PBP: {:.3f}".format(MSE,MAE,PBP))
        print("\n\n")
# Out:
# ####### image 1/9 - image idx 0 ########
#   0%|          | 0/1024 [00:00<?, ?it/s]
# MSE: 2.017  ---  MAE: 0.778  ---  PBP: 0.234
#
#
#
# ####### image 2/9 - image idx 1 ########
#   0%|          | 0/1024 [00:00<?, ?it/s]
# MSE: 1.636  ---  MAE: 0.758  ---  PBP: 0.225
#
#
#
# ####### image 3/9 - image idx 2 ########
#   0%|          | 0/1024 [00:00<?, ?it/s]
# MSE: 1.279  ---  MAE: 0.567  ---  PBP: 0.142
#
#
#
# ####### image 4/9 - image idx 3 ########
#   0%|          | 0/1024 [00:00<?, ?it/s]
# MSE: 1.463  ---  MAE: 0.692  ---  PBP: 0.199
#
#
#
# ####### image 5/9 - image idx 4 ########
#   0%|          | 0/1024 [00:00<?, ?it/s]
# MSE: 1.887  ---  MAE: 0.746  ---  PBP: 0.208
#
#
#
# ####### image 6/9 - image idx 5 ########
#   0%|          | 0/1024 [00:00<?, ?it/s]
# MSE: 1.964  ---  MAE: 0.759  ---  PBP: 0.214
#
#
#
# ####### image 7/9 - image idx 6 ########
#   0%|          | 0/1024 [00:00<?, ?it/s]
# MSE: 2.741  ---  MAE: 0.836  ---  PBP: 0.224
#
#
#
# ####### image 8/9 - image idx 7 ########
#   0%|          | 0/1024 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3334549/259679902.py in <module>
#      14     bicubic_target_img = bicubic(source_img=source_img, scaling_factor=params['scaling'])
#      15
# ---> 16     predicted_target_img = PixTransform(guide_img=guide_img,source_img=source_img,params=params,target_img=target_img)
#      17
#      18
#
# ~/Desktop/mingchi/PixTransform-master/pix_transform/pix_transform.py in PixTransform(source_img, guide_img, params, target_img)
#     127                 source_patch_consistency = myloss(y_mean_pred, y)
#     128
# --> 129                 source_patch_consistency.backward()
#     130                 optimizer.step()
#     131
#
# ~/.local/lib/python3.8/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# ~/.local/lib/python3.8/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     152         retain_graph = create_graph
#     153
# --> 154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %% [markdown]
# ### Change upsampling to 64

# %%
####  define parameters  ########################################################
params = {'img_idxs' : [], # idx images to process, if empty then all of them
            
          'scaling': 16,
          'greyscale': False, # Turn image into grey-scale
          'channels': -1,
          
          'spatial_features_input': True,
          'weights_regularizer': [0.0001, 0.001, 0.0001], # spatial color head
          'loss': 'l1',
 
          'optim': 'adam',
          'lr': 0.001,
                  
          'batch_size': 32,
          'iteration': 1024*30*45//32,
                  
          'logstep': 64,
          
          'final_TGV' : False, # Total Generalized Variation in post-processing
          'align': False, # Move image around for evaluation in case guide image and target image are not perfectly aligned
          'delta_PBP': 1, # Delta for percentage of bad pixels 
         }

# %%
if len(params['img_idxs'])==0:
    idxs = np.array(range(0,target_imgs.shape[0]))
else:
    idxs = params['img_idxs']

for n_image,idx in enumerate(idxs):
    
    print("####### image {}/{} - image idx {} ########".format(n_image+1,len(idxs),idx))
    
    guide_img = guide_imgs[idx]
    target_img = target_imgs[idx]
    source_img = downsample(target_img,params['scaling'])

    bicubic_target_img = bicubic(source_img=source_img, scaling_factor=params['scaling'])
    
    predicted_target_img = PixTransform(guide_img=guide_img,source_img=source_img,params=params,target_img=target_img)
    


    if params['final_TGV'] :
        print("applying TGV...")
        predicted_target_img = tvgen(predicted_target_img,[0.1, 0.1],[1, 2],[1, 1])
        
    if params['align'] :
        print("aligning...")
        target_img,predicted_target_img = align_images(target_img,predicted_target_img)

    f, ax = plot_result(guide_img,source_img,predicted_target_img,bicubic_target_img,target_img)
    plt.show()
    
    if target_img is not None:
        # compute metrics and plot results
        MSE = np.mean((predicted_target_img - target_img) ** 2)
        MAE = np.mean(np.abs(predicted_target_img - target_img))
        PBP = np.mean(np.abs(predicted_target_img - target_img) > params["delta_PBP"])

        print("MSE: {:.3f}  ---  MAE: {:.3f}  ---  PBP: {:.3f}".format(MSE,MAE,PBP))
        print("\n\n")
# Out:
# ####### image 1/9 - image idx 0 ########
#   0%|          | 0/1024 [00:00<?, ?it/s]

# %%
# for i in range(2):
#     os.environ["CUDA_AVAILABLE_DEVICES"] = str(i)
#     print(torch.cuda.device_count())
# Out:
# 2
# 2

# %%
torch.cuda.get_device_name()
# Out:
# 'NVIDIA GeForce RTX 2070 SUPER'

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
torch.cuda.set_device(0)
